# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("movie_rating.csv")

# %%
keys = df["source"].unique()
keys
# Out:
# array(['Jack Matthews', 'Mick LaSalle', 'Claudia Puig', 'Lisa Rose',
#        'Toby', 'Gene Seymour'], dtype=object)

# %%
df = df.set_index("source")
df.head()
# Out:
#                            target  rating
# source
# Jack Matthews   Lady in the Water     3.0
# Jack Matthews   Snakes on a Plane     4.0
# Jack Matthews   You Me and Dupree     3.5
# Jack Matthews    Superman Returns     5.0
# Jack Matthews  The Night Listener     3.0

# %%
movies = df["target"].unique()
movies
# Out:
# array(['Lady in the Water', 'Snakes on a Plane', 'You Me and Dupree',
#        'Superman Returns', 'The Night Listener', 'Just My Luck'],
#       dtype=object)

# %%
df_result = pd.DataFrame(0, index=keys, columns=movies, )
df_result
# Out:
#                Lady in the Water  Snakes on a Plane  You Me and Dupree  \
# Jack Matthews                  0                  0                  0
# Mick LaSalle                   0                  0                  0
# Claudia Puig                   0                  0                  0
# Lisa Rose                      0                  0                  0
# Toby                           0                  0                  0
# Gene Seymour                   0                  0                  0
#
#                Superman Returns  The Night Listener  Just My Luck
# Jack Matthews                 0                   0             0
# Mick LaSalle                  0                   0             0
# Claudia Puig                  0                   0             0
# Lisa Rose                     0                   0             0
# Toby                          0                   0             0
# Gene Seymour                  0                   0             0

# %%
df.head()
# Out:
#                            target  rating
# source
# Jack Matthews   Lady in the Water     3.0
# Jack Matthews   Snakes on a Plane     4.0
# Jack Matthews   You Me and Dupree     3.5
# Jack Matthews    Superman Returns     5.0
# Jack Matthews  The Night Listener     3.0

# %%
df.groupby(["source", "target"]).sum().head()
# Out:
#                                  rating
# source       target
# Claudia Puig Just My Luck           3.0
#              Snakes on a Plane      3.5
#              The Night Listener     4.5
# Gene Seymour Lady in the Water      3.0
#              Snakes on a Plane      3.5

# %%
result1 = df.groupby(["source", "target"]).sum().unstack().fillna(0)
result1
# Out:
#                     rating                                      \
# target        Just My Luck Lady in the Water Snakes on a Plane
# source
# Claudia Puig           3.0               0.0               3.5
# Gene Seymour           0.0               3.0               3.5
# Jack Matthews          0.0               3.0               4.0
# Lisa Rose              3.0               2.5               3.5
# Mick LaSalle           2.0               3.0               4.0
# Toby                   0.0               0.0               4.5
#
#
# target        Superman Returns The Night Listener You Me and Dupree
# source
# Claudia Puig               0.0                4.5               0.0
# Gene Seymour               0.0                3.0               3.5
# Jack Matthews              5.0                3.0               3.5
# Lisa Rose                  3.5                3.0               2.5
# Mick LaSalle               3.0                3.0               0.0
# ...

# %%
# Out:
# target         Just My Luck  Lady in the Water  Snakes on a Plane  \
# source
# Claudia Puig            3.0                NaN                3.5
# Gene Seymour            NaN                3.0                3.5
# Jack Matthews           NaN                3.0                4.0
# Lisa Rose               3.0                2.5                3.5
# Mick LaSalle            2.0                3.0                4.0
# Toby                    NaN                NaN                4.5
#
# target         Superman Returns  The Night Listener  You Me and Dupree
# source
# Claudia Puig                NaN                 4.5                NaN
# Gene Seymour                NaN                 3.0                3.5
# Jack Matthews               5.0                 3.0                3.5
# Lisa Rose                   3.5                 3.0                2.5
# Mick LaSalle                3.0                 3.0                NaN
# ...
